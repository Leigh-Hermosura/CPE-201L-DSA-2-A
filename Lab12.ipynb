# %% [markdown]
# <a href="https://colab.research.google.com/github/Leigh-Hermosura/CPE-201L-DSA-2-A/blob/main/Lab12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque
import time

class Graph:
    def __init__(self):
        self.adj_list = {}

    def add_vertex(self, vertex):
        if vertex not in self.adj_list:
            self.adj_list[vertex] = []

    def add_edge(self, vertex1, vertex2, directed=False):
        self.add_vertex(vertex1)
        self.add_vertex(vertex2)

        self.adj_list[vertex1].append(vertex2)
        if not directed:
            self.adj_list[vertex2].append(vertex1)

    def display(self):
        for vertex, neighbors in self.adj_list.items():
            print(f"{vertex}: {neighbors}")

    def dfs_recursive(self, start, visited=None, path=None):
        if visited is None:
            visited = set()
        if path is None:
            path = []

        visited.add(start)
        path.append(start)
        print(f"Visiting: {start}")

        for neighbor in self.adj_list[start]:
            if neighbor not in visited:
                self.dfs_recursive(neighbor, visited, path)

        return path

    def dfs_iterative(self, start):
        visited = set()
        stack = [start]
        path = []

        print("DFS Iterative Traversal:")
        while stack:
            vertex = stack.pop()
            if vertex not in visited:
                visited.add(vertex)
                path.append(vertex)
                print(f"Visiting: {vertex}")

                # Add neighbors in reverse order for consistent order
                for neighbor in reversed(self.adj_list[vertex]):
                    if neighbor not in visited:
                        stack.append(neighbor)
        return path

    def bfs(self, start):
        visited = set()
        queue = deque([start])
        path = []

        print("BFS Traversal:")
        while queue:
            vertex = queue.popleft()
            if vertex not in visited:
                visited.add(vertex)
                path.append(vertex)
                print(f"Visiting: {vertex}")

                for neighbor in self.adj_list[vertex]:
                    if neighbor not in visited:
                        queue.append(neighbor)

        return path

G = Graph()

G.add_vertex('A')
G.add_vertex('B')
G.add_vertex('C')
G.add_vertex('D')
G.display()

print()

G.add_edge('A', 'B')
G.add_edge('A', 'C')
G.add_edge('A', 'D')
G.add_edge('C', 'D')
G.add_edge('B', 'D')
G.display()
print()


print(f"DFS Recursive Path: {G.dfs_recursive('A')}")
print()
print(f"\nDFS Iterative Path: {G.dfs_iterative('A')}")
print()
print("\nBFS Path:", G.bfs('A'))
# Out:
# A: []
# B: []
# C: []
# D: []
#
# A: ['B', 'C', 'D']
# B: ['A', 'D']
# C: ['A', 'D']
# D: ['A', 'C', 'B']
#
# Visiting: A
# Visiting: B
# Visiting: D
# Visiting: C
# DFS Recursive Path: ['A', 'B', 'D', 'C']
#
# DFS Iterative Traversal:
# Visiting: A
# Visiting: B
# Visiting: D
# Visiting: C
#
# DFS Iterative Path: ['A', 'B', 'D', 'C']
#
# BFS Traversal:
# Visiting: A
# Visiting: B
# Visiting: C
# Visiting: D
#
# BFS Path: ['A', 'B', 'C', 'D']
